# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import random
import torch.nn.functional as F
#environment
import gym
import os
import time
#pytorch
import torch
from torch.autograd import Variable
import torch.nn as nn
from math import sqrt


logging_interval = 40
animate_interval = logging_interval * 5
logdir='./DDPG/'

# %%
VISUALIZE = False
SEED = 0
MAX_PATH_LENGTH = 500
NUM_EPISODES = 12000
GAMMA=0.99
BATCH_SIZE = 128

# Environments to be tested on
env_name = 'InvertedPendulum-v1'
#env_name = 'Pendulum-v0'
#env_name = 'HalfCheetah-v1' 

# wrap gym to save videos
env = gym.make(env_name)
if VISUALIZE:
    if not os.path.exists(logdir):
        os.mkdir(logdir)
    env = gym.wrappers.Monitor(env, logdir, force=True, video_callable=lambda episode_id: episode_id%logging_interval==0)
env._max_episodes_steps = MAX_PATH_LENGTH

# check observation and action space
discrete = isinstance(env.action_space, gym.spaces.Discrete)
obs_dim = env.observation_space.shape[0]
act_dim = env.action_space.n if discrete else env.action_space.shape[0]

if discrete:
    print("This is a discrete action space, probably not the right algorithm to use")

# set random seeds
torch.manual_seed(SEED)
np.random.seed(SEED)

# make variable types for automatic setting to GPU or CPU, depending on GPU availability
use_cuda = torch.cuda.is_available()
FloatTensor = torch.cuda.FloatTensor if use_cuda else torch.FloatTensor
LongTensor = torch.cuda.LongTensor if use_cuda else torch.LongTensor
ByteTensor = torch.cuda.ByteTensor if use_cuda else torch.ByteTensor
Tensor = FloatTensor
# Out:
# [2018-06-03 20:46:09,696] Making new env: InvertedPendulum-v1

# %%
class NormalizeAction(gym.ActionWrapper):
    def action(self, action):
        action = (action + 1) / 2  
        action *= (self.action_space.high - self.action_space.low)
        action += self.action_space.low
        return action

    def reverse_action(self, action):
        action -= self.action_space.low
        action /= (self.action_space.high - self.action_space.low)
        a
        ction = action * 2 - 1
        return actions

# %%
def weightSync(target_model, source_model, tau = 0.001):
    for parameter_target, parameter_source in zip(target_model.parameters(), source_model.parameters()):
        parameter_target.data.copy_((1 - tau) * parameter_target.data + tau * parameter_source.data)

# %%
from collections import deque
import random

class Replay(object):
    def __init__(self, maxlen = 60000):
        self.maxlen = maxlen
        #self.data = deque(maxlen = self.maxlen)
        self.data=[]
        self.position=0

        self.initialize(init_length=1000, envir=env)
    def initialize(self,init_length=1000, envir=env):
        s = envir.reset()
        for i in range (init_length):
            #a = np.random.random(1)-np.random.random(1)
            a = env.action_space.sample()
            s1, r, done, _ = env.step(a)            
            self.add([np.reshape(s,(1,obs_dim)), np.reshape(a,(1,act_dim)), r, done, np.reshape(s1,(1,obs_dim))])
                        
            if done:
                s=envir.reset()
            else: 
                s = s1  
             
         
    def add(self, ep):
        self.data.append(ep)
        self.position = (self.position + 1) % self.maxlen       
        #self.data[self.position] = tuple(ep)
        
    def sample(self, nsamples):
        if nsamples > len(self.data):
            return random.sample(self.data, len(self.data))
        else:
            return random.sample(self.data, nsamples)

    def display(self):
        for x in self.data:
            print (x)

# %%
class OrnsteinUhlenbeckProcess:
    def __init__(self, mu=np.zeros(act_dim), sigma=0.05, theta=.25, dimension=1e-2, x0=None,num_steps=12000):
        self.theta = theta
        self.mu = mu
        self.sigma = sigma
        self.dt = dimension
        self.x0 = x0
        self.reset()

    def step(self):
        x = self.x_prev + self.theta * (self.mu - self.x_prev) * self.dt + \
                self.sigma * np.sqrt(self.dt) * np.random.normal(size=self.mu.shape)
        self.x_prev = x
        return x

    def reset(self):
        self.x_prev = self.x0 if self.x0 is not None else np.zeros_like(self.mu)

    def __repr__(self):
        return 'OrnsteinUhlenbeckActionNoise(mu={}, sigma={})'.format(self.mu, self.sigma)

# %%
# ----------------------------------------------------
# actor model, MLP
# ----------------------------------------------------
# 2 hidden layers, 400 units per layer, tanh output to bound outputs between -1 and 1

class critic(nn.Module):

    def __init__(self, state_size, action_size,output_size = 1):
        super(critic, self).__init__()

        self.state_dim = state_size
        self.action_dim = action_size
        h1_dim = 300
        h2_dim = 300

        self.fc1 = nn.Linear(self.state_dim,h1_dim)
        
        #self.bn1 = nn.BatchNorm1d(h1_dim)
        
        self.fc2 = nn.Linear(h1_dim + self.action_dim,h2_dim)
        
        self.fc3 = nn.Linear(h2_dim,output_size)


    def forward(self, sa):
        state, action =sa
        #s1 = F.relu(self.bn1(self.fc1(state)))
        s1 = F.relu(self.fc1(state))

        x = torch.cat((s1,action),dim=1)
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


class actor(nn.Module):

    def __init__(self, input_size, output_size):
        super(actor, self).__init__()

        self.state_dim = input_size
        self.action_dim = output_size
        h1_dim = 400
        h2_dim = 400

        self.fc1 = nn.Linear(self.state_dim,h1_dim)
        #self.bn1 = nn.BatchNorm1d(h1_dim)

        self.fc2 = nn.Linear(h1_dim,h2_dim)
        #self.bn2 = nn.BatchNorm1d(h2_dim)

        self.fc3 = nn.Linear(h2_dim,self.action_dim)

        
    def forward(self, state):
        #x = F.relu(self.bn1(self.fc1(state)))
        #x = F.relu(self.bn2(self.fc2(x)))
        
        x = F.relu(self.fc1(state))
        x = F.relu(self.fc2(x))
        action = F.tanh(self.fc3(x))

        return action

# %%
class DDPG:
    def __init__(self, obs_dim, act_dim, critic_lr = 1e-3, actor_lr = 1e-4, gamma = GAMMA, batch_size = BATCH_SIZE):
        
        self.gamma = GAMMA
        self.batch_size = BATCH_SIZE
        
        # actor
        self.actor = actor(input_size = obs_dim, output_size = act_dim).type(FloatTensor)
        self.actor_perturbed = actor(input_size = obs_dim, output_size = act_dim).type(FloatTensor)
        self.actor_target = actor(input_size = obs_dim, output_size = act_dim).type(FloatTensor)
        self.actor_target.load_state_dict(self.actor.state_dict())

        # critic
        self.critic = critic(state_size = obs_dim, action_size = act_dim, output_size = 1).type(FloatTensor)
        self.critic_target = critic(state_size = obs_dim, action_size = act_dim, output_size = 1).type(FloatTensor)
        self.critic_target.load_state_dict(self.critic.state_dict())
        if use_cuda:
            self.actor.cuda()
            self.actor_target.cuda()
            self.critic.cuda()
            self.critic_target.cuda()
        # optimizers
        self.optimizer_actor = torch.optim.Adam(self.actor.parameters(), lr = actor_lr)
        self.optimizer_critic = torch.optim.Adam(self.critic.parameters(), lr = critic_lr, weight_decay=1e-2)
        
        # critic loss
        self.critic_loss = nn.MSELoss()
        
        # noise
        self.noise = OrnsteinUhlenbeckProcess(dimension = act_dim, num_steps = NUM_EPISODES)

        # replay buffer 
        self.replayBuffer = Replay()

        
    def action(self, s, noise, para):
        obs = torch.from_numpy(s).unsqueeze(0)
        inp = Variable(obs,requires_grad=False).type(FloatTensor)

        self.actor.eval()
        self.actor_perturbed.eval()

        if para is not None:
            a = self.actor_perturbed(inp).data[0].cpu().numpy() 
        else:
            a = self.actor(inp).data[0].cpu().numpy() 
        self.actor.train()

        if noise is not None:
            a = a + noise
        return a
    

    def perturb_actor_parameters(self, param_noise):
        """Apply parameter noise to actor model, for exploration"""
        hard_update(self.actor_perturbed, self.actor)
        params = self.actor_perturbed.state_dict()
        for name in params:
            if 'ln' in name: 
                pass 
            param = params[name]
            random = torch.randn(param.shape)
            if use_cuda:
                random = random.cuda()
            param += random * param_noise.current_stddev
    
    
    def train(self,training_data):
        # sample from Replay
        batch_s = np.vstack(training_data[:,0])
        batch_a = np.vstack(training_data[:,1])
        batch_s1 = np.vstack(training_data[:,4])
        batch_r = np.array(training_data[:,2]).astype("float")
        batch_done = np.array(training_data[:,3]).astype("float")
        
        s1 = Variable(torch.from_numpy(batch_s)).type(FloatTensor)
        a1 = Variable(torch.from_numpy(batch_a)).type(FloatTensor)
        r1 = Variable(torch.from_numpy(batch_r[:,None]),volatile = True).type(FloatTensor)
        s2 = Variable(torch.from_numpy(batch_s1), volatile = True).type(FloatTensor)
        d  = Variable(torch.from_numpy(1.0*batch_done)[:,None]).type(FloatTensor)

       
        a2 = self.actor_target.forward(s2)
        # ---------------------- optimize critic ----------------------

        next_val = self.critic_target((s2, a2)).detach()
        
        q_expected = r1 + self.gamma*next_val*(1.0-d)
        
        # y_pred = Q( s1, a1)
        q_predicted = self.critic((s1, a1))

        
        #print (y_predicted.volatile)
        #print (y_expected.volatile)

        # compute critic loss, and update the critic
        loss_critic = self.critic_loss(q_predicted, q_expected)
        self.optimizer_critic.zero_grad()
        #print (loss_critic.volatile)
        loss_critic.backward()
        self.optimizer_critic.step()

        # ---------------------- optimize actor ----------------------
        pred_a1 = self.actor.forward(s1)
        loss_actor = -1*self.critic.forward((s1, pred_a1))
        loss_actor = loss_actor.mean()
        #input()
        self.optimizer_actor.zero_grad()
        loss_actor.backward()
        #print (loss_actor.volatile)
        self.optimizer_actor.step()
        
        # sychronize target network with fast moving one
        weightSync(self.critic_target, self.critic)
        weightSync(self.actor_target, self.actor)

# %%
ddpg = DDPG(obs_dim = obs_dim, act_dim = act_dim)
# print(ddpg.actor)
# print(ddpg.critic)

# %%
class AdaptiveParamNoiseSpec(object):
    def __init__(self, initial_stddev=0.1, desired_action_stddev=0.2, adaptation_coefficient=1.01):
        """
        Note that initial_stddev and current_stddev refer to std of parameter noise, 
        but desired_action_stddev refers to (as name notes) desired std in action space
        """
        self.initial_stddev = initial_stddev
        self.desired_action_stddev = desired_action_stddev
        self.adaptation_coefficient = adaptation_coefficient

        self.current_stddev = initial_stddev

    def adapt(self, distance):
        if distance > self.desired_action_stddev:
            # Decrease stddev.
            self.current_stddev /= self.adaptation_coefficient
        else:
            # Increase stddev.
            self.current_stddev *= self.adaptation_coefficient

    def get_stats(self):
        stats = {
            'param_noise_stddev': self.current_stddev,
        }
        return stats

    def __repr__(self):
        fmt = 'AdaptiveParamNoiseSpec(initial_stddev={}, desired_action_stddev={}, adaptation_coefficient={})'
        return fmt.format(self.initial_stddev, self.desired_action_stddev, self.adaptation_coefficient)

def ddpg_distance_metric(actions1, actions2):
    """
    Compute "distance" between actions taken by two policies at the same states
    Expects numpy arrays
    """
    diff = actions1-actions2
    mean_diff = np.mean(np.square(diff), axis=0)
    dist = sqrt(np.mean(mean_diff))
    return dist


def hard_update(target, source):
    for target_param, param in zip(target.parameters(), source.parameters()):
           target_param.data.copy_(param.data)

# %%
env = NormalizeAction(env) # remap action values for the environment
avg_val = 0

#for plotting
running_rewards_ddpg = []
step_list_ddpg = []
step_counter = 0

# set term_condition for early stopping according to environment being used
#term_condition = -150 # Pendulum
term_condition = 500 # inverted Pendulum
# term_condition = 1500 # half cheetah

param_noise = AdaptiveParamNoiseSpec(initial_stddev=0.05,desired_action_stddev=0.3, adaptation_coefficient=1.05)

for itr in range(NUM_EPISODES):
    s=env.reset() # get initial state
    animate_this_episode = (itr % animate_interval == 0) and VISUALIZE
    total_reward=0
    ddpg.perturb_actor_parameters(param_noise)
    #actor_noise = OrnsteinUhlenbeckProcess(mu=np.zeros(act_dim))
    noise_counter=0
    while True:
        ddpg.noise.reset()
        if animate_this_episode:
                env.render('rgb_array')
                time.sleep(0.05)
        a = ddpg.action(s, ddpg.noise.step(),param_noise)
        #a = ddpg.action(s, None, param_noise)
        s1, r, done, _ = env.step(a)
        total_reward += r

        ddpg.replayBuffer.add([np.reshape(s,(1,obs_dim)), np.reshape(a,(1,act_dim)), r, done, np.reshape(s1,(1,obs_dim))])
        s = np.copy(s1)

        training_data = np.array(ddpg.replayBuffer.sample(BATCH_SIZE))
        ddpg.train(training_data)
        step_counter += 1
        noise_counter +=1
        if done:
            break
            
    if ddpg.replayBuffer.position-noise_counter > 0:
            noise_data=ddpg.replayBuffer.data[ddpg.replayBuffer.position-noise_counter:ddpg.replayBuffer.position]
    else:
           noise_data=ddpg.replayBuffer.data[ddpg.replayBuffer.position-noise_counter+60000:60000] \
            + ddpg.replayBuffer.data[0:ddpg.replayBuffer.position]
    noise_data=np.array(noise_data)
    noise_s = np.vstack(noise_data[:,0])
    noise_a = np.vstack(noise_data[:,1])

    perturbed_actions = noise_a
    unperturbed_actions = ddpg.action(noise_s, None, None)
    ddpg_dist = ddpg_distance_metric(perturbed_actions, unperturbed_actions)
    
    param_noise.adapt(ddpg_dist)
    
    if itr > 100 and avg_val > term_condition:
            break
    running_rewards_ddpg.append(total_reward) # return of this episode
    step_list_ddpg.append(step_counter)

    avg_val = avg_val * 0.95 + 0.05*running_rewards_ddpg[-1]
    print("Average value: {} for episode: {}".format(avg_val,itr))
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:78: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:79: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# Average value: 0.8 for episode: 0
# Average value: 2.66 for episode: 1
# Average value: 2.677 for episode: 2
# Average value: 2.6931499999999997 for episode: 3
# Average value: 2.7084924999999993 for episode: 4
# Average value: 2.723067874999999 for episode: 5
# Average value: 2.736914481249999 for episode: 6
# Average value: 2.700068757187499 for episode: 7
# Average value: 2.6650653193281237 for episode: 8
# Average value: 2.681812053361717 for episode: 9
# Average value: 2.697721450693631 for episode: 10
# Average value: 2.6628353781589493 for episode: 11
# Average value: 2.6796936092510015 for episode: 12
# Average value: 2.6457089287884514 for episode: 13
# Average value: 2.6134234823490288 for episode: 14
# Average value: 2.632752308231577 for episode: 15
# Average value: 2.651114692819998 for episode: 16
# Average value: 2.668558958178998 for episode: 17
# Average value: 2.635131010270048 for episode: 18
# Average value: 2.6033744597565454 for episode: 19
# Average value: 2.623205736768718 for episode: 20
# Average value: 2.642045449930282 for episode: 21
# Average value: 2.6599431774337674 for episode: 22
# Average value: 2.676946018562079 for episode: 23
# Average value: 2.643098717633975 for episode: 24
# Average value: 2.6609437817522763 for episode: 25
# Average value: 2.6278965926646625 for episode: 26
# Average value: 2.646501763031429 for episode: 27
# Average value: 2.6141766748798574 for episode: 28
# Average value: 2.6334678411358645 for episode: 29
# Average value: 2.601794449079071 for episode: 30
# Average value: 3.0717047266251174 for episode: 31
# Average value: 3.0181194902938615 for episode: 32
# Average value: 2.9672135157791684 for episode: 33
# Average value: 2.96885283999021 for episode: 34
# Average value: 3.5704101979906993 for episode: 35
# Average value: 3.541889688091164 for episode: 36
# Average value: 3.4647952036866054 for episode: 37
# Average value: 3.441555443502275 for episode: 38
# Average value: 3.3694776713271613 for episode: 39
# Average value: 3.3510037877608028 for episode: 40
# Average value: 3.3334535983727624 for episode: 41
# Average value: 3.366780918454124 for episode: 42
# Average value: 3.2984418725314177 for episode: 43
# Average value: 3.2835197789048465 for episode: 44
# Average value: 3.2193437899596042 for episode: 45
# Average value: 3.158376600461624 for episode: 46
# Average value: 3.1504577704385426 for episode: 47
# Average value: 3.0929348819166154 for episode: 48
# Average value: 3.5382881378207847 for episode: 49
# Average value: 3.5613737309297453 for episode: 50
# Average value: 3.483305044383258 for episode: 51
# Average value: 3.409139792164095 for episode: 52
# Average value: 3.33868280255589 for episode: 53
# Average value: 3.3217486624280954 for episode: 54
# Average value: 3.3056612293066903 for episode: 55
# Average value: 3.2903781678413555 for episode: 56
# Average value: 3.2758592594492875 for episode: 57
# Average value: 3.3120662964768233 for episode: 58
# Average value: 3.246462981652982 for episode: 59
# Average value: 3.2841398325703333 for episode: 60
# Average value: 3.3699328409418166 for episode: 61
# Average value: 3.301436198894726 for episode: 62
# Average value: 3.2863643889499894 for episode: 63
# Average value: 3.32204616950249 for episode: 64
# Average value: 3.3059438610273655 for episode: 65
# Average value: 3.240646667975997 for episode: 66
# Average value: 3.228614334577197 for episode: 67
# Average value: 3.217183617848337 for episode: 68
# Average value: 3.20632443695592 for episode: 69
# Average value: 3.1960082151081237 for episode: 70
# Average value: 3.2362078043527176 for episode: 71
# Average value: 3.3243974141350816 for episode: 72
# Average value: 3.2581775434283275 for episode: 73
# Average value: 3.245268666256911 for episode: 74
# Average value: 3.233005232944065 for episode: 75
# Average value: 3.2713549712968617 for episode: 76
# Average value: 3.557787222732019 for episode: 77
# Average value: 3.5298978615954177 for episode: 78
# Average value: 3.5034029685156467 for episode: 79
# Average value: 3.5282328200898645 for episode: 80
# Average value: 3.5518211790853713 for episode: 81
# Average value: 3.4742301201311028 for episode: 82
# Average value: 3.4505186141245474 for episode: 83
# Average value: 3.37799268341832 for episode: 84
# Average value: 3.3590930492474036 for episode: 85
# Average value: 3.2911383967850334 for episode: 86
# Average value: 3.2265814769457815 for episode: 87
# Average value: 3.2152524030984924 for episode: 88
# Average value: 3.2044897829435675 for episode: 89
# Average value: 3.144265293796389 for episode: 90
# Average value: 3.1870520291065696 for episode: 91
# Average value: 3.127699427651241 for episode: 92
# Average value: 3.171314456268679 for episode: 93
# Average value: 4.162748733455245 for episode: 94
# Average value: 4.054611296782482 for episode: 95
# Average value: 3.9518807319433575 for episode: 96
# Average value: 3.9042866953461894 for episode: 97
# Average value: 4.15907236057888 for episode: 98
# Average value: 4.051118742549935 for episode: 99
# Average value: 3.9985628054224382 for episode: 100
# Average value: 3.948634665151316 for episode: 101
# Average value: 3.85120293189375 for episode: 102
# Average value: 3.808642785299062 for episode: 103
# Average value: 3.718210646034109 for episode: 104
# Average value: 3.6323001137324034 for episode: 105
# Average value: 3.600685108045783 for episode: 106
# Average value: 3.520650852643494 for episode: 107
# Average value: 3.494618310011319 for episode: 108
# Average value: 3.4698873945107525 for episode: 109
# Average value: 3.496393024785215 for episode: 110
# Average value: 3.421573373545954 for episode: 111
# Average value: 3.400494704868656 for episode: 112
# Average value: 3.330469969625223 for episode: 113
# Average value: 3.3139464711439617 for episode: 114
# Average value: 3.2982491475867635 for episode: 115
# Average value: 3.2833366902074252 for episode: 116
# Average value: 3.369169855697054 for episode: 117
# Average value: 3.3007113629122014 for episode: 118
# Average value: 3.2356757947665913 for episode: 119
# Average value: 3.2238920050282616 for episode: 120
# Average value: 3.2626974047768487 for episode: 121
# Average value: 3.199562534538006 for episode: 122
# Average value: 3.1895844078111057 for episode: 123
# Average value: 3.3801051874205505 for episode: 124
# Average value: 3.311099928049523 for episode: 125
# Average value: 3.245544931647047 for episode: 126
# Average value: 3.4332676850646946 for episode: 127
# Average value: 3.36160430081146 for episode: 128
# Average value: 3.443524085770887 for episode: 129
# Average value: 3.421347881482342 for episode: 130
# Average value: 3.450280487408225 for episode: 131
# Average value: 3.3777664630378137 for episode: 132
# Average value: 3.3588781398859227 for episode: 133
# Average value: 3.740934232891626 for episode: 134
# Average value: 3.7038875212470446 for episode: 135
# Average value: 3.668693145184692 for episode: 136
# Average value: 3.6352584879254572 for episode: 137
# Average value: 3.5534955635291845 for episode: 138
# Average value: 3.525820785352725 for episode: 139
# Average value: 3.449529746085089 for episode: 140
# Average value: 3.777053258780834 for episode: 141
# Average value: 3.7382005958417923 for episode: 142
# Average value: 3.7012905660497024 for episode: 143
# Average value: 3.666226037747217 for episode: 144
# Average value: 3.732914735859856 for episode: 145
# Average value: 3.646268999066863 for episode: 146
# Average value: 3.61395554911352 for episode: 147
# Average value: 3.5332577716578437 for episode: 148
# Average value: 3.5565948830749514 for episode: 149
# Average value: 3.528765138921204 for episode: 150
# Average value: 3.4523268819751434 for episode: 151
# Average value: 3.3797105378763863 for episode: 152
# Average value: 3.410725010982567 for episode: 153
# Average value: 3.340188760433439 for episode: 154
# Average value: 3.423179322411767 for episode: 155
# Average value: 3.3520203562911783 for episode: 156
# Average value: 3.4344193384766193 for episode: 157
# Average value: 3.412698371552788 for episode: 158
# Average value: 3.3420634529751485 for episode: 159
# Average value: 3.324960280326391 for episode: 160
# Average value: 3.308712266310071 for episode: 161
# Average value: 3.2932766529945674 for episode: 162
# Average value: 3.328612820344839 for episode: 163
# Average value: 3.362182179327597 for episode: 164
# Average value: 3.444073070361217 for episode: 165
# Average value: 3.3718694168431558 for episode: 166
# Average value: 3.3532759460009975 for episode: 167
# Average value: 3.4356121487009474 for episode: 168
# Average value: 3.4138315412658997 for episode: 169
# Average value: 3.4931399642026046 for episode: 170
# Average value: 3.4184829659924745 for episode: 171
# Average value: 3.4475588176928507 for episode: 172
# Average value: 3.375180876808208 for episode: 173
# Average value: 3.3064218329677977 for episode: 174
# Average value: 3.241100741319408 for episode: 175
# Average value: 3.2790457042534378 for episode: 176
# Average value: 3.2150934190407656 for episode: 177
# Average value: 3.3043387480887274 for episode: 178
# Average value: 3.3391218106842913 for episode: 179
# Average value: 3.2721657201500767 for episode: 180
# Average value: 3.358557434142573 for episode: 181
# Average value: 3.290629562435444 for episode: 182
# Average value: 3.226098084313672 for episode: 183
# Average value: 3.2147931800979883 for episode: 184
# Average value: 3.2040535210930887 for episode: 185
# Average value: 3.1438508450384344 for episode: 186
# Average value: 3.2366583027865126 for episode: 187
# Average value: 3.174825387647187 for episode: 188
# Average value: 3.1160841182648276 for episode: 189
# Average value: 3.0602799123515863 for episode: 190
# Average value: 3.4572659167340065 for episode: 191
# Average value: 3.384402620897306 for episode: 192
# Average value: 3.3651824898524407 for episode: 193
# Average value: 3.2969233653598184 for episode: 194
# Average value: 3.8320771970918277 for episode: 195
# Average value: 3.840473337237236 for episode: 196
# Average value: 3.7484496703753742 for episode: 197
# Average value: 3.6610271868566056 for episode: 198
# Average value: 3.627975827513775 for episode: 199
# Average value: 3.596577036138086 for episode: 200
# Average value: 3.6167481843311817 for episode: 201
# Average value: 3.5859107751146224 for episode: 202
# Average value: 3.506615236358891 for episode: 203
# Average value: 3.4312844745409463 for episode: 204
# Average value: 3.609720250813899 for episode: 205
# Average value: 3.5792342382732034 for episode: 206
# Average value: 3.5002725263595433 for episode: 207
# Average value: 3.425258900041566 for episode: 208
# Average value: 3.453995955039488 for episode: 209
# Average value: 3.3812961572875135 for episode: 210
# Average value: 3.3622313494231375 for episode: 211
# Average value: 3.4441197819519807 for episode: 212
# Average value: 3.4219137928543812 for episode: 213
# Average value: 3.350818103211662 for episode: 214
# Average value: 3.433277198051079 for episode: 215
# Average value: 3.361613338148525 for episode: 216
# Average value: 3.3435326712410984 for episode: 217
# Average value: 3.326356037679043 for episode: 218
# Average value: 3.2600382357950908 for episode: 219
# Average value: 3.247036324005336 for episode: 220
# Average value: 3.2346845078050688 for episode: 221
# Average value: 3.2729502824148153 for episode: 222
# Average value: 3.5593027682940748 for episode: 223
# Average value: 3.7813376298793706 for episode: 224
# Average value: 3.692270748385402 for episode: 225
# Average value: 3.607657210966132 for episode: 226
# Average value: 4.277274350417825 for episode: 227
# Average value: 4.163410632896933 for episode: 228
# Average value: 4.155240101252086 for episode: 229
# Average value: 4.097478096189482 for episode: 230
# Average value: 4.042604191380008 for episode: 231
# Average value: 3.990473981811007 for episode: 232
# Average value: 3.8909502827204565 for episode: 233
# Average value: 3.8464027685844333 for episode: 234
# Average value: 3.8040826301552113 for episode: 235
# Average value: 3.7638784986474505 for episode: 236
# Average value: 3.725684573715078 for episode: 237
# Average value: 3.689400345029324 for episode: 238
# Average value: 3.6049303277778577 for episode: 239
# Average value: 3.524683811388965 for episode: 240
# Average value: 3.448449620819517 for episode: 241
# Average value: 3.4260271397785407 for episode: 242
# Average value: 3.3547257827896138 for episode: 243
# Average value: 3.3369894936501328 for episode: 244
# Average value: 3.270140018967626 for episode: 245
# Average value: 3.2566330180192447 for episode: 246
# Average value: 3.2438013671182824 for episode: 247
# Average value: 3.1816112987623684 for episode: 248
# Average value: 3.12253073382425 for episode: 249
# Average value: 3.0664041971330374 for episode: 250
# Average value: 3.0630839872763853 for episode: 251
# Average value: 3.009929787912566 for episode: 252
# Average value: 3.0594332985169377 for episode: 253
# Average value: 3.5564616335910904 for episode: 254
# Average value: 3.578638551911536 for episode: 255
# Average value: 3.549706624315959 for episode: 256
# Average value: 3.6722212931001605 for episode: 257
# Average value: 3.6886102284451527 for episode: 258
# Average value: 3.654179717022895 for episode: 259
# Average value: 3.62147073117175 for episode: 260
# Average value: 3.590397194613162 for episode: 261
# Average value: 3.5108773348825038 for episode: 262
# Average value: 3.4353334681383787 for episode: 263
# Average value: 3.5135667947314597 for episode: 264
# Average value: 3.5878884549948866 for episode: 265
# Average value: 3.558494032245142 for episode: 266
# Average value: 3.480569330632885 for episode: 267
# Average value: 3.556540864101241 for episode: 268
# Average value: 3.5787138208961786 for episode: 269
# Average value: 3.5497781298513695 for episode: 270
# Average value: 4.872289223358801 for episode: 271
# Average value: 4.878674762190861 for episode: 272
# Average value: 4.934741024081317 for episode: 273
# Average value: 4.888003972877251 for episode: 274
# Average value: 4.793603774233389 for episode: 275
# Average value: 4.7539235855217195 for episode: 276
# Average value: 5.7162274062456335 for episode: 277
# Average value: 6.1804160359333515 for episode: 278
# Average value: 6.771395234136684 for episode: 279
# Average value: 6.5828254724298505 for episode: 280
# Average value: 6.803684198808358 for episode: 281
# Average value: 6.61349998886794 for episode: 282
# Average value: 6.432824989424543 for episode: 283
# Average value: 7.811183739953316 for episode: 284
# Average value: 8.02062455295565 for episode: 285
# Average value: 9.869593325307868 for episode: 286
# Average value: 10.326113659042473 for episode: 287
# Average value: 10.10980797609035 for episode: 288
# Average value: 10.854317577285832 for episode: 289
# Average value: 10.46160169842154 for episode: 290
# Average value: 11.538521613500462 for episode: 291
# Average value: 12.511595532825439 for episode: 292
# Average value: 12.236015756184166 for episode: 293
# Average value: 11.924214968374958 for episode: 294
# Average value: 11.92800421995621 for episode: 295
# Average value: 12.031604008958398 for episode: 296
# Average value: 12.380023808510478 for episode: 297
# Average value: 13.461022618084954 for episode: 298
# Average value: 13.037971487180705 for episode: 299
# Average value: 12.736072912821669 for episode: 300
# Average value: 12.349269267180585 for episode: 301
# Average value: 11.931805803821554 for episode: 302
# Average value: 14.235215513630477 for episode: 303
# Average value: 14.423454737948953 for episode: 304
# Average value: 13.902282001051503 for episode: 305
# Average value: 14.257167900998928 for episode: 306
# Average value: 14.54430950594898 for episode: 307
# Average value: 15.267094030651531 for episode: 308
# Average value: 14.803739329118955 for episode: 309
# Average value: 15.013552362663006 for episode: 310
# Average value: 14.862874744529854 for episode: 311
# Average value: 15.119731007303361 for episode: 312
# Average value: 15.713744456938192 for episode: 313
# Average value: 15.578057234091283 for episode: 314
# Average value: 18.399154372386718 for episode: 315
# Average value: 17.62919665376738 for episode: 316
# Average value: 17.19773682107901 for episode: 317
# Average value: 16.737849980025057 for episode: 318
# Average value: 20.500957481023804 for episode: 319
# Average value: 19.675909606972613 for episode: 320
# Average value: 19.542114126623982 for episode: 321
# Average value: 21.11500842029278 for episode: 322
# Average value: 20.50925799927814 for episode: 323
# Average value: 23.733795099314232 for episode: 324
# Average value: 24.44710534434852 for episode: 325
# Average value: 25.12475007713109 for episode: 326
# Average value: 24.51851257327453 for episode: 327
# Average value: 25.542586944610804 for episode: 328
# Average value: 26.315457597380263 for episode: 329
# Average value: 28.14968471751125 for episode: 330
# Average value: 36.492200481635685 for episode: 331
# Average value: 36.5675904575539 for episode: 332
# Average value: 36.5392109346762 for episode: 333
# Average value: 35.11225038794239 for episode: 334
# Average value: 36.10663786854527 for episode: 335
# Average value: 43.75130597511801 for episode: 336
# Average value: 43.81374067636211 for episode: 337
# Average value: 45.523053642544 for episode: 338
# Average value: 44.6969009604168 for episode: 339
# Average value: 43.91205591239596 for episode: 340
# Average value: 44.766453116776155 for episode: 341
# Average value: 44.47813046093735 for episode: 342
# Average value: 44.40422393789048 for episode: 343
# Average value: 44.884012740995956 for episode: 344
# Average value: 45.139812103946156 for episode: 345
# Average value: 47.13282149874885 for episode: 346
# Average value: 46.9261804238114 for episode: 347
# Average value: 49.029871402620834 for episode: 348
# Average value: 47.37837783248979 for episode: 349
# Average value: 48.5594589408653 for episode: 350
# Average value: 48.331485993822035 for episode: 351
# Average value: 48.214911694130926 for episode: 352
# Average value: 48.604166109424376 for episode: 353
# Average value: 53.02395780395316 for episode: 354
# Average value: 56.5227599137555 for episode: 355
# Average value: 56.49662191806772 for episode: 356
# Average value: 103.67179082216433 for episode: 357
# Average value: 118.2382012810561 for episode: 358
# Average value: 116.22629121700331 for episode: 359
# Average value: 160.41497665615316 for episode: 360
# Average value: 157.1942278233455 for episode: 361
# Average value: 154.83451643217822 for episode: 362
# Average value: 152.3927906105693 for episode: 363
# Average value: 147.62315108004083 for episode: 364
# Average value: 147.1419935260388 for episode: 365
# Average value: 143.68489384973685 for episode: 366
# Average value: 139.10064915725 for episode: 367
# Average value: 139.3956166993875 for episode: 368
# Average value: 148.5258358644181 for episode: 369
# Average value: 151.9995440711972 for episode: 370
# Average value: 147.29956686763734 for episode: 371
# Average value: 154.43458852425547 for episode: 372
# Average value: 150.31285909804268 for episode: 373
# Average value: 152.24721614314052 for episode: 374
# Average value: 147.23485533598347 for episode: 375
# Average value: 142.6731125691843 for episode: 376
# Average value: 143.33945694072509 for episode: 377
# Average value: 138.77248409368883 for episode: 378
# Average value: 135.68385988900437 for episode: 379
# Average value: 142.64966689455414 for episode: 380
# Average value: 141.91718354982643 for episode: 381
# Average value: 137.5713243723351 for episode: 382
# Average value: 136.19275815371836 for episode: 383
# Average value: 148.98312024603243 for episode: 384
# Average value: 148.7839642337308 for episode: 385
# Average value: 144.44476602204426 for episode: 386
# Average value: 144.82252772094205 for episode: 387
# Average value: 142.18140133489493 for episode: 388
# Average value: 155.67233126815017 for episode: 389
# Average value: 162.93871470474267 for episode: 390
# Average value: 162.44177896950552 for episode: 391
# Average value: 158.06969002103023 for episode: 392
# Average value: 178.41620551997872 for episode: 393
# Average value: 175.64539524397978 for episode: 394
# Average value: 170.71312548178076 for episode: 395
# Average value: 168.97746920769174 for episode: 396
# Average value: 164.12859574730714 for episode: 397
# Average value: 161.9721659599418 for episode: 398
# Average value: 156.77355766194472 for episode: 399
# Average value: 155.63487977884748 for episode: 400
# Average value: 156.4531357899051 for episode: 401
# Average value: 155.88047900040985 for episode: 402
# Average value: 150.48645505038937 for episode: 403
# Average value: 152.41213229786987 for episode: 404
# Average value: 146.99152568297637 for episode: 405
# Average value: 189.64194939882753 for episode: 406
# Average value: 191.35985192888614 for episode: 407
# Average value: 188.79185933244182 for episode: 408
# Average value: 184.95226636581972 for episode: 409
# Average value: 189.4046530475287 for episode: 410
# Average value: 183.48442039515228 for episode: 411
# Average value: 184.06019937539466 for episode: 412
# Average value: 181.40718940662492 for episode: 413
# Average value: 178.88682993629368 for episode: 414
# Average value: 178.34248843947898 for episode: 415
# Average value: 175.625364017505 for episode: 416
# Average value: 177.89409581662977 for episode: 417
# Average value: 177.7993910257983 for episode: 418
# Average value: 180.75942147450837 for episode: 419
# Average value: 177.87145040078295 for episode: 420
# Average value: 171.7778778807438 for episode: 421
# Average value: 170.6389839867066 for episode: 422
# Average value: 165.90703478737126 for episode: 423
# Average value: 160.46168304800267 for episode: 424
# Average value: 160.98859889560254 for episode: 425
# Average value: 156.3391689508224 for episode: 426
# Average value: 151.67221050328126 for episode: 427
# Average value: 151.9385999781172 for episode: 428
# Average value: 146.99166997921134 for episode: 429
# Average value: 148.34208648025074 for episode: 430
# Average value: 152.9249821562382 for episode: 431
# Average value: 147.9287330484263 for episode: 432
# Average value: 144.38229639600496 for episode: 433
# Average value: 145.36318157620468 for episode: 434
# Average value: 140.54502249739443 for episode: 435
# Average value: 140.3177713725247 for episode: 436
# Average value: 136.35188280389846 for episode: 437
# Average value: 136.63428866370353 for episode: 438
# Average value: 138.15257423051835 for episode: 439
# Average value: 136.69494551899243 for episode: 440
# Average value: 135.56019824304278 for episode: 441
# Average value: 134.43218833089063 for episode: 442
# Average value: 131.06057891434608 for episode: 443
# Average value: 127.50754996862877 for episode: 444
# Average value: 124.28217247019732 for episode: 445
# Average value: 123.56806384668745 for episode: 446
# Average value: 120.43966065435308 for episode: 447
# Average value: 116.96767762163542 for episode: 448
# Average value: 120.06929374055365 for episode: 449
# Average value: 120.66582905352595 for episode: 450
# Average value: 118.33253760084965 for episode: 451
# Average value: 117.41591072080716 for episode: 452
# Average value: 117.0451151847668 for episode: 453
# Average value: 116.54285942552845 for episode: 454
# Average value: 116.01571645425201 for episode: 455
# Average value: 122.2649306315394 for episode: 456
# Average value: 118.65168409996242 for episode: 457
# Average value: 115.6690998949643 for episode: 458
# Average value: 112.78564490021608 for episode: 459
# Average value: 121.04636265520529 for episode: 460
# Average value: 117.79404452244502 for episode: 461
# Average value: 118.85434229632277 for episode: 462
# Average value: 118.51162518150662 for episode: 463
# Average value: 115.28604392243129 for episode: 464
# Average value: 120.22174172630972 for episode: 465
# Average value: 116.66065463999423 for episode: 466
# Average value: 113.97762190799452 for episode: 467
# Average value: 110.77874081259479 for episode: 468
# Average value: 111.18980377196505 for episode: 469
# Average value: 109.23031358336678 for episode: 470
# Average value: 109.11879790419843 for episode: 471
# Average value: 113.66285800898851 for episode: 472
# Average value: 111.77971510853908 for episode: 473
# Average value: 118.99072935311212 for episode: 474
# Average value: 116.1411928854565 for episode: 475
# Average value: 120.33413324118368 for episode: 476
# Average value: 120.86742657912448 for episode: 477
# Average value: 118.12405525016825 for episode: 478
# Average value: 118.01785248765984 for episode: 479
# Average value: 119.31695986327685 for episode: 480
# Average value: 120.051111870113 for episode: 481
# Average value: 117.29855627660734 for episode: 482
# Average value: 118.83362846277697 for episode: 483
# Average value: 115.2419470396381 for episode: 484
# Average value: 115.6298496876562 for episode: 485
# Average value: 121.2483572032734 for episode: 486
# Average value: 125.33593934310973 for episode: 487
# Average value: 124.76914237595425 for episode: 488
# Average value: 120.98068525715654 for episode: 489
# Average value: 118.13165099429871 for episode: 490
# Average value: 116.52506844458377 for episode: 491
# Average value: 115.69881502235457 for episode: 492
# Average value: 116.26387427123683 for episode: 493
# Average value: 112.90068055767499 for episode: 494
# Average value: 110.40564652979124 for episode: 495
# Average value: 106.98536420330167 for episode: 496
# Average value: 149.18609599313658 for episode: 497
# Average value: 146.97679119347973 for episode: 498
# Average value: 142.32795163380572 for episode: 499
# Average value: 139.76155405211546 for episode: 500
# Average value: 135.0734763495097 for episode: 501
# Average value: 134.1698025320342 for episode: 502
# Average value: 129.96131240543247 for episode: 503
# Average value: 127.91324678516084 for episode: 504
# Average value: 126.41758444590279 for episode: 505
# Average value: 122.59670522360764 for episode: 506
# Average value: 118.31686996242725 for episode: 507
# Average value: 115.90102646430589 for episode: 508
# Average value: 112.60597514109058 for episode: 509
# Average value: 109.67567638403605 for episode: 510
# Average value: 114.14189256483425 for episode: 511
# Average value: 115.38479793659253 for episode: 512
# Average value: 113.1155580397629 for episode: 513
# Average value: 111.20978013777476 for episode: 514
# Average value: 110.24929113088601 for episode: 515
# Average value: 110.3368265743417 for episode: 516
# Average value: 109.1699852456246 for episode: 517
# Average value: 109.41148598334337 for episode: 518
# Average value: 107.3909116841762 for episode: 519
# Average value: 104.4713660999674 for episode: 520
# Average value: 105.39779779496902 for episode: 521
# Average value: 107.32790790522057 for episode: 522
# Average value: 107.71151250995953 for episode: 523
# Average value: 104.57593688446156 for episode: 524
# Average value: 102.14714004023847 for episode: 525
# Average value: 99.23978303822655 for episode: 526
# Average value: 98.02779388631522 for episode: 527
# Average value: 105.87640419199946 for episode: 528
# Average value: 135.2825839823995 for episode: 529
# Average value: 131.8684547832795 for episode: 530
# Average value: 128.9250320441155 for episode: 531
# Average value: 147.77878044190973 for episode: 532
# Average value: 143.53984141981425 for episode: 533
# Average value: 141.91284934882356 for episode: 534
# Average value: 138.01720688138235 for episode: 535
# Average value: 134.06634653731322 for episode: 536
# Average value: 130.86302921044756 for episode: 537
# Average value: 129.4698777499252 for episode: 538
# Average value: 137.14638386242893 for episode: 539
# Average value: 133.0390646693075 for episode: 540
# Average value: 131.43711143584213 for episode: 541
# Average value: 127.46525586405001 for episode: 542
# Average value: 126.99199307084751 for episode: 543
# Average value: 123.34239341730513 for episode: 544
# Average value: 122.12527374643987 for episode: 545
# Average value: 124.46901005911788 for episode: 546
# Average value: 121.54555955616198 for episode: 547
# Average value: 117.66828157835387 for episode: 548
# Average value: 114.33486749943617 for episode: 549
# Average value: 118.56812412446436 for episode: 550
# Average value: 158.58971791824115 for episode: 551
# Average value: 153.4602320223291 for episode: 552
# Average value: 152.38722042121265 for episode: 553
# Average value: 148.01785940015202 for episode: 554
# Average value: 142.6169664301444 for episode: 555
# Average value: 141.8861181086372 for episode: 556
# Average value: 141.34181220320534 for episode: 557
# Average value: 136.67472159304506 for episode: 558
# Average value: 132.49098551339281 for episode: 559
# Average value: 135.26643623772316 for episode: 560
# Average value: 137.003114425837 for episode: 561
# Average value: 133.05295870454515 for episode: 562
# Average value: 136.3003107693179 for episode: 563
# Average value: 133.235295230852 for episode: 564
# Average value: 131.0735304693094 for episode: 565
# Average value: 127.06985394584392 for episode: 566
# Average value: 129.06636124855171 for episode: 567
# Average value: 125.71304318612411 for episode: 568
# Average value: 124.8773910268179 for episode: 569
# Average value: 124.633521475477 for episode: 570
# Average value: 120.50184540170314 for episode: 571
# Average value: 123.12675313161797 for episode: 572
# Average value: 120.57041547503707 for episode: 573
# Average value: 120.7918947012852 for episode: 574
# Average value: 118.25229996622093 for episode: 575
# Average value: 118.03968496790988 for episode: 576
# Average value: 115.03770071951439 for episode: 577
# Average value: 159.28581568353866 for episode: 578
# Average value: 157.1715248993617 for episode: 579
# Average value: 151.2629486543936 for episode: 580
# Average value: 157.3998012216739 for episode: 581
# Average value: 171.37981116059018 for episode: 582
# Average value: 174.21082060256066 for episode: 583
# Average value: 215.50027957243262 for episode: 584
# Average value: 254.72526559381097 for episode: 585
# Average value: 244.33900231412042 for episode: 586
# Average value: 239.5220521984144 for episode: 587
# Average value: 248.94594958849368 for episode: 588
# Average value: 239.148652109069 for episode: 589
# Average value: 229.94121950361554 for episode: 590
# Average value: 227.94415852843474 for episode: 591
# Average value: 227.096950602013 for episode: 592
# Average value: 223.59210307191233 for episode: 593
# Average value: 214.96249791831673 for episode: 594
# Average value: 208.16437302240087 for episode: 595
# Average value: 200.40615437128082 for episode: 596
# Average value: 207.48584665271676 for episode: 597
# Average value: 201.6115543200809 for episode: 598
# Average value: 195.23097660407683 for episode: 599
# Average value: 235.46942777387298 for episode: 600
# Average value: 273.69595638517933 for episode: 601
# Average value: 262.76115856592037 for episode: 602
# Average value: 251.87310063762433 for episode: 603
# Average value: 247.0794456057431 for episode: 604
# Average value: 248.82547332545593 for episode: 605
# Average value: 242.0841996591831 for episode: 606
# Average value: 279.9799896762239 for episode: 607
# Average value: 271.7309901924127 for episode: 608
# Average value: 260.6944406827921 for episode: 609
# Average value: 255.4597186486525 for episode: 610
# Average value: 247.38673271621985 for episode: 611
# Average value: 239.61739608040884 for episode: 612
# Average value: 233.4365262763884 for episode: 613
# Average value: 229.96469996256897 for episode: 614
# Average value: 220.8164649644405 for episode: 615
# Average value: 212.62564171621847 for episode: 616
# Average value: 211.24435963040753 for episode: 617
# Average value: 204.98214164888716 for episode: 618
# Average value: 202.3830345664428 for episode: 619
# Average value: 209.51388283812065 for episode: 620
# Average value: 203.8881886962146 for episode: 621
# Average value: 202.89377926140384 for episode: 622
# Average value: 199.99909029833364 for episode: 623
# Average value: 193.59913578341695 for episode: 624
# Average value: 187.9191789942461 for episode: 625
# Average value: 192.3232200445338 for episode: 626
# Average value: 202.15705904230708 for episode: 627
# Average value: 198.09920609019173 for episode: 628
# Average value: 193.09424578568215 for episode: 629
# Average value: 190.33953349639805 for episode: 630
# Average value: 187.42255682157813 for episode: 631
# Average value: 228.05142898049922 for episode: 632
# Average value: 231.24885753147424 for episode: 633
# Average value: 222.18641465490052 for episode: 634
# Average value: 217.7270939221555 for episode: 635
# Average value: 219.4907392260477 for episode: 636
# Average value: 219.51620226474532 for episode: 637
# Average value: 220.14039215150802 for episode: 638
# Average value: 259.13337254393264 for episode: 639
# Average value: 253.27670391673598 for episode: 640
# Average value: 250.06286872089916 for episode: 641
# Average value: 243.30972528485418 for episode: 642
# Average value: 236.14423902061145 for episode: 643
# Average value: 229.03702706958086 for episode: 644
# Average value: 246.48517571610182 for episode: 645
# Average value: 242.6609169302967 for episode: 646
# Average value: 235.22787108378185 for episode: 647
# Average value: 226.76647752959275 for episode: 648
# Average value: 265.4281536531131 for episode: 649
# Average value: 260.10674597045744 for episode: 650
# Average value: 262.4014086719346 for episode: 651
# Average value: 256.93133823833784 for episode: 652
# Average value: 250.53477132642092 for episode: 653
# Average value: 240.55803276009988 for episode: 654
# Average value: 233.98013112209486 for episode: 655
# Average value: 228.3311245659901 for episode: 656
# Average value: 218.86456833769057 for episode: 657
# Average value: 215.82133992080603 for episode: 658
# Average value: 217.08027292476572 for episode: 659
# Average value: 211.27625927852745 for episode: 660
# Average value: 250.71244631460107 for episode: 661
# Average value: 247.57682399887102 for episode: 662
# Average value: 245.59798279892746 for episode: 663
# Average value: 283.3180836589811 for episode: 664
# Average value: 272.25217947603204 for episode: 665
# Average value: 264.98957050223044 for episode: 666
# Average value: 254.54009197711892 for episode: 667
# Average value: 291.81308737826294 for episode: 668
# Average value: 279.9724330093498 for episode: 669
# Average value: 268.8238113588823 for episode: 670
# Average value: 283.5826207909382 for episode: 671
# Average value: 272.8034897513913 for episode: 672
# Average value: 276.06331526382166 for episode: 673
# Average value: 312.2601495006306 for episode: 674
# Average value: 346.647142025599 for episode: 675
# Average value: 343.41478492431906 for episode: 676
# Average value: 332.4940456781031 for episode: 677
# Average value: 365.8693433941979 for episode: 678
# Average value: 356.775876224488 for episode: 679
# Average value: 354.08708241326354 for episode: 680
# Average value: 346.43272829260036 for episode: 681
# Average value: 338.66109187797036 for episode: 682
# Average value: 371.72803728407183 for episode: 683
# Average value: 403.14163541986824 for episode: 684
# Average value: 392.13455364887477 for episode: 685
# Average value: 422.527825966431 for episode: 686
# Average value: 410.60143466810945 for episode: 687
# Average value: 398.22136293470396 for episode: 688
# Average value: 428.31029478796876 for episode: 689
# Average value: 456.8947800485703 for episode: 690
# Average value: 484.05004104614176 for episode: 691
# Average value: 509.84753899383463 for episode: 692

# %%
def numpy_ewma_vectorized_v2(data, window):

    alpha = 2 /(window + 1.0)
    alpha_rev = 1-alpha
    n = data.shape[0]

    pows = alpha_rev**(np.arange(n+1))

    scale_arr = 1/pows[:-1]
    offset = data[0]*pows[1:]
    pw0 = alpha*alpha_rev**(n-1)

    mult = data*pw0*scale_arr
    cumsums = mult.cumsum()
    out = offset + cumsums*scale_arr[::-1]
    return out

plt.figure()
out = numpy_ewma_vectorized_v2(np.array(running_rewards_ddpg),20)
step_list_ddpg = np.array(step_list_ddpg)

plt.plot(step_list_ddpg, out)
plt.title('Training reward over multiple runs')
plt.xlabel('Number of steps')
plt.ylabel('Cumulative reward')
plt.show()

# %%
np.save('out.npy',out)
np.save('step_list_ddpg.npy',step_list_ddpg)

# %%
torch.save(ddpg.actor, 'FINALWEIGHTS_InvertedPendulum_actor.pt')
torch.save(ddpg.actor_perturbed, 'FINALWEIGHTS_InvertedPendulum_actor_perturbed.pt')
np.save('param_noise.npy',[param_noise.desired_action_stddev,
                           param_noise.adaptation_coefficient,
                           param_noise.current_stddev])
# Out:
# /opt/conda/lib/python3.6/site-packages/torch/serialization.py:193: UserWarning: Couldn't retrieve source code for container of type actor. It won't be checked for correctness upon loading.
#   "type " + obj.__name__ + ". It won't be checked "

# %%
pnl = np.load('param_noise.npy')
ddpg.actor = torch.load('FINALWEIGHTS_InvertedPendulum_actor.pt')
ddpg.actor_perturbed = torch.load('FINALWEIGHTS_InvertedPendulum_actor_perturbed.pt')

# %%
env_name = 'InvertedPendulum-v1'
env1 = gym.make(env_name)

# check whether the environment is discrete or continuous
discrete = isinstance(env.action_space, gym.spaces.Discrete)
obs_dim = env1.observation_space.shape[0]
act_dim = env1.action_space.n if discrete else env.action_space.shape[0]
if discrete: print("This is a discrete action space, probably not the right algorithm to use")


logdir='./DDPG_final/'
logging_interval = 20
animate_interval = logging_interval * 5
VISUALIZE = True
if VISUALIZE:
    if not os.path.exists(logdir):
        os.mkdir(logdir)
    env1 = gym.wrappers.Monitor(env1, logdir, force=True, video_callable=lambda \
                               episode_id: episode_id%logging_interval==0)
env1._max_episodes_steps = MAX_PATH_LENGTH

env1 = NormalizeAction(env1) # remap action values for the environment
# Out:
# [2018-06-03 20:53:59,601] Making new env: InvertedPendulum-v1
# [2018-06-03 20:53:59,610] Clearing 2 monitor files from previous run (because force=True was provided)

# %%
for i in range(2):
    SEED = 0   
    torch.manual_seed(SEED)
    np.random.seed(SEED)
    s1 = env1.reset() # get initial state
    # env1.render()
    # time.sleep(0.05)
    count=0
    param_noise = AdaptiveParamNoiseSpec(pnl[2],pnl[0],pnl[1])
    while True: # for each episode, we loop each step in this episode
        ddpg.noise.reset()
        env1.render()
        time.sleep(0.05)
        # use actor to get action, add ddpg.noise.step() to action
        # remember to put NN in eval mode while testing (to deal with BatchNorm layers) and put it back 
        # to train mode after you're done getting the action
        a1 = ddpg.action(s1, ddpg.noise.step(), param_noise)
        s1_1, r1, done1, _ = env1.step(a1)
        s1 = s1_1
        if done1: break
        count+=1
print('Finish Visualization')
# Out:
# [2018-06-03 20:53:59,653] Starting new video recorder writing to /datasets/home/63/963/yuh379/ee276c/final project/DDPG_final/openaigym.video.0.420.video000000.mp4
# [2018-06-03 20:53:59,655] GLFW error: 65544, desc: b'X11: RandR gamma ramp support seems broken'
# [2018-06-03 20:53:59,698] GLFW error: 65544, desc: b'Linux: Failed to watch for joystick connections in /dev/input: No such file or directory'
# [2018-06-03 20:53:59,700] GLFW error: 65544, desc: b'Linux: Failed to open joystick device directory /dev/input: No such file or directory'
# Finish Visualization

# %%
count
# Out:
# 999

# %%
out=np.load('out.npy')
step_list_ddpg=np.load('step_list_ddpg.npy')

plt.plot(step_list_ddpg, out)
plt.title('Training reward over multiple runs')
plt.xlabel('Number of steps')
plt.ylabel('Cumulative reward')
plt.show()
